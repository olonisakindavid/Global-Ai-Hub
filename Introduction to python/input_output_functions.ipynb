# %%
print("Hi, this is Python")
# Out:
# Global AI Hub!

# %%
name = "Deniz"
print(name)
# Out:
# Deniz

# %%
name = "Selin"
print('Hello', name)
# Out:
# Hello Selin

# %%
print(15)
# Out:
# 15

# %%
name = input('Name:')
print('Greetings', name)
# Out:
# Running cells with 'c:\Users\Pavilion\AppData\Local\Programs\Python\Python310\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Pavilion/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
number = input("Number: ")
print(number + 10)
# Out:
# Number: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a07d619c15d2> in <module>()
#       1 number = input("Number: ")
# ----> 2 print(number + 10)
#
# TypeError: can only concatenate str (not "int") to str

# %%
number = int(input("Number: "))
print(number + 10)
# Out:
# Number: 5
# 15
